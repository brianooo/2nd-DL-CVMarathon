# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive/AI/Day044'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/AI/Day044

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0068 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00235, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 0.0018 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00235 to 0.00195, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 0.0014 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00195 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00188 to 0.00186, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss improved from 0.00186 to 0.00186, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00186 to 0.00186, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 9.6479e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00186 to 0.00175, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 8.3853e-04 - val_loss: 0.0016
#
# Epoch 00008: val_loss improved from 0.00175 to 0.00162, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 7.4311e-04 - val_loss: 0.0014
#
# Epoch 00009: val_loss improved from 0.00162 to 0.00137, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 6.3135e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00137 to 0.00121, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 0s 195us/step - loss: 5.5853e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00121 to 0.00113, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 5.0430e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00113 to 0.00107, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 4.6512e-04 - val_loss: 0.0010
#
# Epoch 00013: val_loss improved from 0.00107 to 0.00104, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 4.2943e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss did not improve from 0.00104
# Epoch 15/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 4.1015e-04 - val_loss: 9.7073e-04
#
# Epoch 00015: val_loss improved from 0.00104 to 0.00097, saving model to best_weights.h5
# Epoch 16/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 3.8003e-04 - val_loss: 9.3839e-04
#
# Epoch 00016: val_loss improved from 0.00097 to 0.00094, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 3.7064e-04 - val_loss: 9.3156e-04
#
# Epoch 00017: val_loss improved from 0.00094 to 0.00093, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 3.5376e-04 - val_loss: 9.4329e-04
#
# Epoch 00018: val_loss did not improve from 0.00093
# Epoch 19/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 3.4848e-04 - val_loss: 9.3870e-04
#
# Epoch 00019: val_loss did not improve from 0.00093
# Epoch 20/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 3.2117e-04 - val_loss: 8.5039e-04
#
# Epoch 00020: val_loss improved from 0.00093 to 0.00085, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 0s 189us/step - loss: 3.1743e-04 - val_loss: 8.7122e-04
#
# Epoch 00021: val_loss did not improve from 0.00085
# Epoch 22/150
# 1712/1712 [==============================] - 0s 196us/step - loss: 3.0150e-04 - val_loss: 8.4226e-04
#
# Epoch 00022: val_loss improved from 0.00085 to 0.00084, saving model to best_weights.h5
# Epoch 23/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 2.8977e-04 - val_loss: 8.4864e-04
#
# Epoch 00023: val_loss did not improve from 0.00084
# Epoch 24/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 2.9207e-04 - val_loss: 8.3377e-04
#
# Epoch 00024: val_loss improved from 0.00084 to 0.00083, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 2.8305e-04 - val_loss: 8.7126e-04
#
# Epoch 00025: val_loss did not improve from 0.00083
# Epoch 26/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 2.7147e-04 - val_loss: 8.6159e-04
#
# Epoch 00026: val_loss did not improve from 0.00083
# Epoch 27/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 2.6118e-04 - val_loss: 8.4582e-04
#
# Epoch 00027: val_loss did not improve from 0.00083
# Epoch 28/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 2.6251e-04 - val_loss: 8.4481e-04
#
# Epoch 00028: val_loss did not improve from 0.00083
# Epoch 29/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 2.4940e-04 - val_loss: 7.9352e-04
#
# Epoch 00029: val_loss improved from 0.00083 to 0.00079, saving model to best_weights.h5
# Epoch 30/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 2.4831e-04 - val_loss: 7.9838e-04
#
# Epoch 00030: val_loss did not improve from 0.00079
# Epoch 31/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 2.4740e-04 - val_loss: 8.1458e-04
#
# Epoch 00031: val_loss did not improve from 0.00079
# Epoch 32/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 2.4259e-04 - val_loss: 7.8440e-04
#
# Epoch 00032: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 33/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 2.4181e-04 - val_loss: 8.2307e-04
#
# Epoch 00033: val_loss did not improve from 0.00078
# Epoch 34/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 2.2769e-04 - val_loss: 8.0324e-04
#
# Epoch 00034: val_loss did not improve from 0.00078
# Epoch 35/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 2.3089e-04 - val_loss: 8.0696e-04
#
# Epoch 00035: val_loss did not improve from 0.00078
# Epoch 36/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 2.2532e-04 - val_loss: 8.0173e-04
#
# Epoch 00036: val_loss did not improve from 0.00078
# Epoch 37/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 2.2186e-04 - val_loss: 7.7502e-04
#
# Epoch 00037: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 2.1771e-04 - val_loss: 7.9523e-04
#
# Epoch 00038: val_loss did not improve from 0.00078
# Epoch 39/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 2.1380e-04 - val_loss: 8.1682e-04
#
# Epoch 00039: val_loss did not improve from 0.00078
# Epoch 40/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 2.1859e-04 - val_loss: 8.2044e-04
#
# Epoch 00040: val_loss did not improve from 0.00078
# Epoch 41/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 2.1629e-04 - val_loss: 7.9760e-04
#
# Epoch 00041: val_loss did not improve from 0.00078
# Epoch 42/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 2.0592e-04 - val_loss: 8.0499e-04
#
# Epoch 00042: val_loss did not improve from 0.00078
# Epoch 43/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 2.0106e-04 - val_loss: 7.7985e-04
#
# Epoch 00043: val_loss did not improve from 0.00078
# Epoch 44/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.9544e-04 - val_loss: 7.8107e-04
#
# Epoch 00044: val_loss did not improve from 0.00078
# Epoch 45/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.9816e-04 - val_loss: 7.9820e-04
#
# Epoch 00045: val_loss did not improve from 0.00078
# Epoch 46/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.9154e-04 - val_loss: 7.7491e-04
#
# Epoch 00046: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.8898e-04 - val_loss: 8.0070e-04
#
# Epoch 00047: val_loss did not improve from 0.00077
# Epoch 48/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.8848e-04 - val_loss: 7.7370e-04
#
# Epoch 00048: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 49/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.8722e-04 - val_loss: 7.7240e-04
#
# Epoch 00049: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 50/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.8755e-04 - val_loss: 7.6876e-04
#
# Epoch 00050: val_loss improved from 0.00077 to 0.00077, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.8357e-04 - val_loss: 8.2382e-04
#
# Epoch 00051: val_loss did not improve from 0.00077
# Epoch 52/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.7780e-04 - val_loss: 7.8950e-04
#
# Epoch 00052: val_loss did not improve from 0.00077
# Epoch 53/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.7569e-04 - val_loss: 7.8994e-04
#
# Epoch 00053: val_loss did not improve from 0.00077
# Epoch 54/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.7592e-04 - val_loss: 8.0349e-04
#
# Epoch 00054: val_loss did not improve from 0.00077
# Epoch 55/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.6897e-04 - val_loss: 7.7104e-04
#
# Epoch 00055: val_loss did not improve from 0.00077
# Epoch 56/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.7353e-04 - val_loss: 7.9581e-04
#
# Epoch 00056: val_loss did not improve from 0.00077
# Epoch 57/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.7010e-04 - val_loss: 7.8895e-04
#
# Epoch 00057: val_loss did not improve from 0.00077
# Epoch 58/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.6627e-04 - val_loss: 7.8396e-04
#
# Epoch 00058: val_loss did not improve from 0.00077
# Epoch 59/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.7034e-04 - val_loss: 7.6308e-04
#
# Epoch 00059: val_loss improved from 0.00077 to 0.00076, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.6386e-04 - val_loss: 7.8638e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.6083e-04 - val_loss: 8.1611e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.5934e-04 - val_loss: 8.1847e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.5576e-04 - val_loss: 7.8102e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.6258e-04 - val_loss: 7.9574e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.6025e-04 - val_loss: 7.6114e-04
#
# Epoch 00065: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 66/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.5563e-04 - val_loss: 7.9447e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.4968e-04 - val_loss: 7.6695e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.5758e-04 - val_loss: 7.8356e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.5287e-04 - val_loss: 7.6213e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.6014e-04 - val_loss: 8.0239e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.5592e-04 - val_loss: 7.6579e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.4742e-04 - val_loss: 7.9069e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.4538e-04 - val_loss: 7.6598e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.4089e-04 - val_loss: 7.9161e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.4401e-04 - val_loss: 7.6353e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.4282e-04 - val_loss: 7.8611e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.4073e-04 - val_loss: 8.0233e-04
#
# Epoch 00077: val_loss did not improve from 0.00076
# Epoch 78/150
# 1712/1712 [==============================] - 0s 192us/step - loss: 1.3603e-04 - val_loss: 7.8020e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.3587e-04 - val_loss: 7.7216e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 0s 185us/step - loss: 1.3222e-04 - val_loss: 8.0386e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.3122e-04 - val_loss: 7.7344e-04
#
# Epoch 00081: val_loss did not improve from 0.00076
# Epoch 82/150
# 1712/1712 [==============================] - 0s 206us/step - loss: 1.3605e-04 - val_loss: 7.7548e-04
#
# Epoch 00082: val_loss did not improve from 0.00076
# Epoch 83/150
# 1712/1712 [==============================] - 0s 199us/step - loss: 1.3206e-04 - val_loss: 7.9535e-04
#
# Epoch 00083: val_loss did not improve from 0.00076
# Epoch 84/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.3651e-04 - val_loss: 8.1810e-04
#
# Epoch 00084: val_loss did not improve from 0.00076
# Epoch 85/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.3433e-04 - val_loss: 7.6185e-04
#
# Epoch 00085: val_loss did not improve from 0.00076
# Epoch 86/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.2795e-04 - val_loss: 7.8669e-04
#
# Epoch 00086: val_loss did not improve from 0.00076
# Epoch 87/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.2119e-04 - val_loss: 7.8909e-04
#
# Epoch 00087: val_loss did not improve from 0.00076
# Epoch 88/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.2387e-04 - val_loss: 7.9760e-04
#
# Epoch 00088: val_loss did not improve from 0.00076
# Epoch 89/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.2424e-04 - val_loss: 8.1388e-04
#
# Epoch 00089: val_loss did not improve from 0.00076
# Epoch 90/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.2444e-04 - val_loss: 7.7105e-04
#
# Epoch 00090: val_loss did not improve from 0.00076
# Epoch 91/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.2438e-04 - val_loss: 7.8835e-04
#
# Epoch 00091: val_loss did not improve from 0.00076
# Epoch 92/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.2324e-04 - val_loss: 7.9098e-04
#
# Epoch 00092: val_loss did not improve from 0.00076
# Epoch 93/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.2130e-04 - val_loss: 7.9754e-04
#
# Epoch 00093: val_loss did not improve from 0.00076
# Epoch 94/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 1.2286e-04 - val_loss: 7.9728e-04
#
# Epoch 00094: val_loss did not improve from 0.00076
# Epoch 95/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.2114e-04 - val_loss: 7.6013e-04
#
# Epoch 00095: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 96/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.1758e-04 - val_loss: 7.6776e-04
#
# Epoch 00096: val_loss did not improve from 0.00076
# Epoch 97/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.2053e-04 - val_loss: 7.5845e-04
#
# Epoch 00097: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 98/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.2294e-04 - val_loss: 8.1964e-04
#
# Epoch 00098: val_loss did not improve from 0.00076
# Epoch 99/150
# 1712/1712 [==============================] - 0s 191us/step - loss: 1.2276e-04 - val_loss: 7.9224e-04
#
# Epoch 00099: val_loss did not improve from 0.00076
# Epoch 100/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.1748e-04 - val_loss: 7.4300e-04
#
# Epoch 00100: val_loss improved from 0.00076 to 0.00074, saving model to best_weights.h5
# Epoch 101/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.1629e-04 - val_loss: 7.8442e-04
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 1.1641e-04 - val_loss: 7.8736e-04
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.1319e-04 - val_loss: 7.8987e-04
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.1122e-04 - val_loss: 7.5628e-04
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 1.1146e-04 - val_loss: 8.0580e-04
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.0684e-04 - val_loss: 7.8435e-04
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.0903e-04 - val_loss: 8.0136e-04
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.0710e-04 - val_loss: 7.8089e-04
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.0630e-04 - val_loss: 7.9808e-04
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 1.1033e-04 - val_loss: 7.7276e-04
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 1.0932e-04 - val_loss: 7.8429e-04
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.1100e-04 - val_loss: 8.0353e-04
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.1129e-04 - val_loss: 8.2415e-04
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 1712/1712 [==============================] - 0s 190us/step - loss: 1.0620e-04 - val_loss: 7.9509e-04
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 1.0311e-04 - val_loss: 8.0260e-04
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 1.0436e-04 - val_loss: 7.8309e-04
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 1712/1712 [==============================] - 0s 174us/step - loss: 1.0201e-04 - val_loss: 7.5530e-04
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 1.0144e-04 - val_loss: 7.6791e-04
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.0027e-04 - val_loss: 7.9332e-04
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 1.0166e-04 - val_loss: 7.8275e-04
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 1712/1712 [==============================] - 0s 187us/step - loss: 9.9383e-05 - val_loss: 7.8911e-04
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 1.0098e-04 - val_loss: 7.8997e-04
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.0288e-04 - val_loss: 7.8736e-04
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 1.0284e-04 - val_loss: 7.9247e-04
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 1.0489e-04 - val_loss: 8.2528e-04
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 1712/1712 [==============================] - 0s 208us/step - loss: 1.0569e-04 - val_loss: 8.0566e-04
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 1712/1712 [==============================] - 0s 186us/step - loss: 9.6090e-05 - val_loss: 7.7527e-04
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 9.5280e-05 - val_loss: 7.7814e-04
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 9.6859e-05 - val_loss: 7.7821e-04
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 1712/1712 [==============================] - 0s 182us/step - loss: 9.3975e-05 - val_loss: 8.0569e-04
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 9.3532e-05 - val_loss: 8.0534e-04
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 9.4925e-05 - val_loss: 7.9161e-04
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 1712/1712 [==============================] - 0s 176us/step - loss: 9.5125e-05 - val_loss: 7.8478e-04
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 9.4399e-05 - val_loss: 7.6670e-04
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 9.3207e-05 - val_loss: 8.2549e-04
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 9.2809e-05 - val_loss: 8.3430e-04
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 1712/1712 [==============================] - 0s 175us/step - loss: 9.1576e-05 - val_loss: 7.6722e-04
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 1712/1712 [==============================] - 0s 184us/step - loss: 9.2831e-05 - val_loss: 7.5826e-04
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 9.2578e-05 - val_loss: 8.1489e-04
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 1712/1712 [==============================] - 0s 183us/step - loss: 9.0931e-05 - val_loss: 7.9770e-04
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 1712/1712 [==============================] - 0s 181us/step - loss: 9.0800e-05 - val_loss: 7.9563e-04
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 8.8019e-05 - val_loss: 7.6356e-04
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 1712/1712 [==============================] - 0s 173us/step - loss: 8.9827e-05 - val_loss: 8.0649e-04
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 1712/1712 [==============================] - 0s 180us/step - loss: 9.1246e-05 - val_loss: 7.9033e-04
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 1712/1712 [==============================] - 0s 177us/step - loss: 8.9595e-05 - val_loss: 7.9032e-04
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 8.8666e-05 - val_loss: 7.9597e-04
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 1712/1712 [==============================] - 0s 179us/step - loss: 8.7665e-05 - val_loss: 7.9150e-04
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 1712/1712 [==============================] - 0s 188us/step - loss: 8.8101e-05 - val_loss: 7.8734e-04
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 1712/1712 [==============================] - 0s 178us/step - loss: 8.7704e-05 - val_loss: 8.4136e-04
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 1712/1712 [==============================] - 0s 172us/step - loss: 8.8907e-05 - val_loss: 7.8155e-04
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_aug.h5', verbose=1, save_best_only=True)
hist_aug = History()

# %%
# Your code

imgs_train_append = np.zeros(imgs_train.shape)
points_train_append = np.zeros(points_train.shape)

for i in range(len(imgs_train)):
    imgs_train_append[i] = imgs_train[i][:, ::-1]
    for j in range(0, 30, 2):
        points_train_append[i][j] = 0.5 - points_train[i][j]
        points_train_append[i][j+1] = points_train[i][j+1]

imgs_train_aug = np.vstack((imgs_train, imgs_train_append))
points_train_aug = np.vstack((points_train, points_train_append))

print(imgs_train_aug.shape, points_train_aug.shape)
# Out:
# (4280, 96, 96) (4280, 30)

# %%
# training the model
hist_model_aug = model_with_augment.fit(imgs_train_aug.reshape(-1, 96, 96, 1), 
                                        points_train_aug, 
                                        validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                                        shuffle=True, epochs=150, verbose=1)
# save the model weights
model_with_augment.save_weights('weights_aug.h5')
# save the model
model_with_augment.save('model_aug.h5')
# Out:
# Train on 3424 samples, validate on 856 samples
# Epoch 1/150
# 3424/3424 [==============================] - 1s 322us/step - loss: 0.0497 - val_loss: 0.1218
#
# Epoch 00001: val_loss did not improve from 0.00074
# Epoch 2/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 0.0305 - val_loss: 0.1444
#
# Epoch 00002: val_loss did not improve from 0.00074
# Epoch 3/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 0.0173 - val_loss: 0.1517
#
# Epoch 00003: val_loss did not improve from 0.00074
# Epoch 4/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 0.0115 - val_loss: 0.1414
#
# Epoch 00004: val_loss did not improve from 0.00074
# Epoch 5/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 0.0080 - val_loss: 0.1219
#
# Epoch 00005: val_loss did not improve from 0.00074
# Epoch 6/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 0.0061 - val_loss: 0.1310
#
# Epoch 00006: val_loss did not improve from 0.00074
# Epoch 7/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 0.0041 - val_loss: 0.1419
#
# Epoch 00007: val_loss did not improve from 0.00074
# Epoch 8/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 0.0030 - val_loss: 0.1272
#
# Epoch 00008: val_loss did not improve from 0.00074
# Epoch 9/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 0.0022 - val_loss: 0.1380
#
# Epoch 00009: val_loss did not improve from 0.00074
# Epoch 10/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 0.0019 - val_loss: 0.1389
#
# Epoch 00010: val_loss did not improve from 0.00074
# Epoch 11/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 0.0014 - val_loss: 0.1372
#
# Epoch 00011: val_loss did not improve from 0.00074
# Epoch 12/150
# 3424/3424 [==============================] - 1s 212us/step - loss: 0.0012 - val_loss: 0.1357
#
# Epoch 00012: val_loss did not improve from 0.00074
# Epoch 13/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 0.0011 - val_loss: 0.1332
#
# Epoch 00013: val_loss did not improve from 0.00074
# Epoch 14/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 0.0010 - val_loss: 0.1365
#
# Epoch 00014: val_loss did not improve from 0.00074
# Epoch 15/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 9.5086e-04 - val_loss: 0.1362
#
# Epoch 00015: val_loss did not improve from 0.00074
# Epoch 16/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.9210e-04 - val_loss: 0.1346
#
# Epoch 00016: val_loss did not improve from 0.00074
# Epoch 17/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 8.6476e-04 - val_loss: 0.1339
#
# Epoch 00017: val_loss did not improve from 0.00074
# Epoch 18/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 9.7207e-04 - val_loss: 0.1402
#
# Epoch 00018: val_loss did not improve from 0.00074
# Epoch 19/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 7.9292e-04 - val_loss: 0.1359
#
# Epoch 00019: val_loss did not improve from 0.00074
# Epoch 20/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 7.2178e-04 - val_loss: 0.1392
#
# Epoch 00020: val_loss did not improve from 0.00074
# Epoch 21/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 6.9235e-04 - val_loss: 0.1333
#
# Epoch 00021: val_loss did not improve from 0.00074
# Epoch 22/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 6.7731e-04 - val_loss: 0.1370
#
# Epoch 00022: val_loss did not improve from 0.00074
# Epoch 23/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 6.4464e-04 - val_loss: 0.1353
#
# Epoch 00023: val_loss did not improve from 0.00074
# Epoch 24/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 6.2609e-04 - val_loss: 0.1391
#
# Epoch 00024: val_loss did not improve from 0.00074
# Epoch 25/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 5.9983e-04 - val_loss: 0.1388
#
# Epoch 00025: val_loss did not improve from 0.00074
# Epoch 26/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 5.9246e-04 - val_loss: 0.1377
#
# Epoch 00026: val_loss did not improve from 0.00074
# Epoch 27/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 5.8406e-04 - val_loss: 0.1396
#
# Epoch 00027: val_loss did not improve from 0.00074
# Epoch 28/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 5.6691e-04 - val_loss: 0.1389
#
# Epoch 00028: val_loss did not improve from 0.00074
# Epoch 29/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 5.5192e-04 - val_loss: 0.1426
#
# Epoch 00029: val_loss did not improve from 0.00074
# Epoch 30/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 5.4014e-04 - val_loss: 0.1370
#
# Epoch 00030: val_loss did not improve from 0.00074
# Epoch 31/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 5.3033e-04 - val_loss: 0.1349
#
# Epoch 00031: val_loss did not improve from 0.00074
# Epoch 32/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 5.1560e-04 - val_loss: 0.1377
#
# Epoch 00032: val_loss did not improve from 0.00074
# Epoch 33/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 5.0868e-04 - val_loss: 0.1366
#
# Epoch 00033: val_loss did not improve from 0.00074
# Epoch 34/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 5.1442e-04 - val_loss: 0.1441
#
# Epoch 00034: val_loss did not improve from 0.00074
# Epoch 35/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 4.9491e-04 - val_loss: 0.1378
#
# Epoch 00035: val_loss did not improve from 0.00074
# Epoch 36/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.8913e-04 - val_loss: 0.1392
#
# Epoch 00036: val_loss did not improve from 0.00074
# Epoch 37/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 4.7082e-04 - val_loss: 0.1389
#
# Epoch 00037: val_loss did not improve from 0.00074
# Epoch 38/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 4.7352e-04 - val_loss: 0.1441
#
# Epoch 00038: val_loss did not improve from 0.00074
# Epoch 39/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.9058e-04 - val_loss: 0.1420
#
# Epoch 00039: val_loss did not improve from 0.00074
# Epoch 40/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 4.7662e-04 - val_loss: 0.1375
#
# Epoch 00040: val_loss did not improve from 0.00074
# Epoch 41/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 4.5727e-04 - val_loss: 0.1503
#
# Epoch 00041: val_loss did not improve from 0.00074
# Epoch 42/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.4927e-04 - val_loss: 0.1330
#
# Epoch 00042: val_loss did not improve from 0.00074
# Epoch 43/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 4.3752e-04 - val_loss: 0.1385
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 4.3360e-04 - val_loss: 0.1404
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.2953e-04 - val_loss: 0.1360
#
# Epoch 00045: val_loss did not improve from 0.00074
# Epoch 46/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.1862e-04 - val_loss: 0.1362
#
# Epoch 00046: val_loss did not improve from 0.00074
# Epoch 47/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.1495e-04 - val_loss: 0.1393
#
# Epoch 00047: val_loss did not improve from 0.00074
# Epoch 48/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.4068e-04 - val_loss: 0.1289
#
# Epoch 00048: val_loss did not improve from 0.00074
# Epoch 49/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 0.0011 - val_loss: 0.2006
#
# Epoch 00049: val_loss did not improve from 0.00074
# Epoch 50/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 0.0133 - val_loss: 0.1457
#
# Epoch 00050: val_loss did not improve from 0.00074
# Epoch 51/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 0.0056 - val_loss: 0.1299
#
# Epoch 00051: val_loss did not improve from 0.00074
# Epoch 52/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 0.0035 - val_loss: 0.1362
#
# Epoch 00052: val_loss did not improve from 0.00074
# Epoch 53/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 0.0029 - val_loss: 0.1455
#
# Epoch 00053: val_loss did not improve from 0.00074
# Epoch 54/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 0.0019 - val_loss: 0.1290
#
# Epoch 00054: val_loss did not improve from 0.00074
# Epoch 55/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 0.0018 - val_loss: 0.1316
#
# Epoch 00055: val_loss did not improve from 0.00074
# Epoch 56/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 0.0015 - val_loss: 0.1357
#
# Epoch 00056: val_loss did not improve from 0.00074
# Epoch 57/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 0.0013 - val_loss: 0.1225
#
# Epoch 00057: val_loss did not improve from 0.00074
# Epoch 58/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 0.0012 - val_loss: 0.1308
#
# Epoch 00058: val_loss did not improve from 0.00074
# Epoch 59/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 9.3021e-04 - val_loss: 0.1333
#
# Epoch 00059: val_loss did not improve from 0.00074
# Epoch 60/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 8.4526e-04 - val_loss: 0.1500
#
# Epoch 00060: val_loss did not improve from 0.00074
# Epoch 61/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 7.7811e-04 - val_loss: 0.1372
#
# Epoch 00061: val_loss did not improve from 0.00074
# Epoch 62/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 6.9438e-04 - val_loss: 0.1359
#
# Epoch 00062: val_loss did not improve from 0.00074
# Epoch 63/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 6.3105e-04 - val_loss: 0.1360
#
# Epoch 00063: val_loss did not improve from 0.00074
# Epoch 64/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 5.9591e-04 - val_loss: 0.1362
#
# Epoch 00064: val_loss did not improve from 0.00074
# Epoch 65/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 5.7972e-04 - val_loss: 0.1348
#
# Epoch 00065: val_loss did not improve from 0.00074
# Epoch 66/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 5.7546e-04 - val_loss: 0.1348
#
# Epoch 00066: val_loss did not improve from 0.00074
# Epoch 67/150
# 3424/3424 [==============================] - 1s 210us/step - loss: 5.5009e-04 - val_loss: 0.1359
#
# Epoch 00067: val_loss did not improve from 0.00074
# Epoch 68/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 5.3357e-04 - val_loss: 0.1367
#
# Epoch 00068: val_loss did not improve from 0.00074
# Epoch 69/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 5.3651e-04 - val_loss: 0.1367
#
# Epoch 00069: val_loss did not improve from 0.00074
# Epoch 70/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 5.2569e-04 - val_loss: 0.1358
#
# Epoch 00070: val_loss did not improve from 0.00074
# Epoch 71/150
# 3424/3424 [==============================] - 1s 211us/step - loss: 5.1217e-04 - val_loss: 0.1396
#
# Epoch 00071: val_loss did not improve from 0.00074
# Epoch 72/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 5.1300e-04 - val_loss: 0.1365
#
# Epoch 00072: val_loss did not improve from 0.00074
# Epoch 73/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 4.9921e-04 - val_loss: 0.1369
#
# Epoch 00073: val_loss did not improve from 0.00074
# Epoch 74/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 4.8902e-04 - val_loss: 0.1382
#
# Epoch 00074: val_loss did not improve from 0.00074
# Epoch 75/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 4.7905e-04 - val_loss: 0.1385
#
# Epoch 00075: val_loss did not improve from 0.00074
# Epoch 76/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.9209e-04 - val_loss: 0.1387
#
# Epoch 00076: val_loss did not improve from 0.00074
# Epoch 77/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.8873e-04 - val_loss: 0.1386
#
# Epoch 00077: val_loss did not improve from 0.00074
# Epoch 78/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.6756e-04 - val_loss: 0.1365
#
# Epoch 00078: val_loss did not improve from 0.00074
# Epoch 79/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.5519e-04 - val_loss: 0.1386
#
# Epoch 00079: val_loss did not improve from 0.00074
# Epoch 80/150
# 3424/3424 [==============================] - 1s 213us/step - loss: 4.6056e-04 - val_loss: 0.1346
#
# Epoch 00080: val_loss did not improve from 0.00074
# Epoch 81/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 4.5118e-04 - val_loss: 0.1394
#
# Epoch 00081: val_loss did not improve from 0.00074
# Epoch 82/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 4.3446e-04 - val_loss: 0.1384
#
# Epoch 00082: val_loss did not improve from 0.00074
# Epoch 83/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.4030e-04 - val_loss: 0.1364
#
# Epoch 00083: val_loss did not improve from 0.00074
# Epoch 84/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 4.2972e-04 - val_loss: 0.1381
#
# Epoch 00084: val_loss did not improve from 0.00074
# Epoch 85/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.4194e-04 - val_loss: 0.1389
#
# Epoch 00085: val_loss did not improve from 0.00074
# Epoch 86/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 4.2784e-04 - val_loss: 0.1382
#
# Epoch 00086: val_loss did not improve from 0.00074
# Epoch 87/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.1453e-04 - val_loss: 0.1380
#
# Epoch 00087: val_loss did not improve from 0.00074
# Epoch 88/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 4.1974e-04 - val_loss: 0.1335
#
# Epoch 00088: val_loss did not improve from 0.00074
# Epoch 89/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.1318e-04 - val_loss: 0.1394
#
# Epoch 00089: val_loss did not improve from 0.00074
# Epoch 90/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.1401e-04 - val_loss: 0.1325
#
# Epoch 00090: val_loss did not improve from 0.00074
# Epoch 91/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 4.1554e-04 - val_loss: 0.1389
#
# Epoch 00091: val_loss did not improve from 0.00074
# Epoch 92/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 4.0958e-04 - val_loss: 0.1370
#
# Epoch 00092: val_loss did not improve from 0.00074
# Epoch 93/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 4.0587e-04 - val_loss: 0.1377
#
# Epoch 00093: val_loss did not improve from 0.00074
# Epoch 94/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 5.0465e-04 - val_loss: 0.1340
#
# Epoch 00094: val_loss did not improve from 0.00074
# Epoch 95/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 6.2423e-04 - val_loss: 0.1415
#
# Epoch 00095: val_loss did not improve from 0.00074
# Epoch 96/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 0.0029 - val_loss: 0.1177
#
# Epoch 00096: val_loss did not improve from 0.00074
# Epoch 97/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 0.0020 - val_loss: 0.1294
#
# Epoch 00097: val_loss did not improve from 0.00074
# Epoch 98/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 0.0020 - val_loss: 0.1289
#
# Epoch 00098: val_loss did not improve from 0.00074
# Epoch 99/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 0.0016 - val_loss: 0.1375
#
# Epoch 00099: val_loss did not improve from 0.00074
# Epoch 100/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 0.0018 - val_loss: 0.1440
#
# Epoch 00100: val_loss did not improve from 0.00074
# Epoch 101/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 0.0010 - val_loss: 0.1408
#
# Epoch 00101: val_loss did not improve from 0.00074
# Epoch 102/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 8.4132e-04 - val_loss: 0.1351
#
# Epoch 00102: val_loss did not improve from 0.00074
# Epoch 103/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 0.0011 - val_loss: 0.1268
#
# Epoch 00103: val_loss did not improve from 0.00074
# Epoch 104/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 7.2995e-04 - val_loss: 0.1321
#
# Epoch 00104: val_loss did not improve from 0.00074
# Epoch 105/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 6.0593e-04 - val_loss: 0.1324
#
# Epoch 00105: val_loss did not improve from 0.00074
# Epoch 106/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 5.1950e-04 - val_loss: 0.1357
#
# Epoch 00106: val_loss did not improve from 0.00074
# Epoch 107/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 4.9106e-04 - val_loss: 0.1341
#
# Epoch 00107: val_loss did not improve from 0.00074
# Epoch 108/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 4.7886e-04 - val_loss: 0.1373
#
# Epoch 00108: val_loss did not improve from 0.00074
# Epoch 109/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.6307e-04 - val_loss: 0.1395
#
# Epoch 00109: val_loss did not improve from 0.00074
# Epoch 110/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 4.6019e-04 - val_loss: 0.1372
#
# Epoch 00110: val_loss did not improve from 0.00074
# Epoch 111/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.5697e-04 - val_loss: 0.1390
#
# Epoch 00111: val_loss did not improve from 0.00074
# Epoch 112/150
# 3424/3424 [==============================] - 1s 208us/step - loss: 4.3576e-04 - val_loss: 0.1377
#
# Epoch 00112: val_loss did not improve from 0.00074
# Epoch 113/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.3269e-04 - val_loss: 0.1387
#
# Epoch 00113: val_loss did not improve from 0.00074
# Epoch 114/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.4069e-04 - val_loss: 0.1383
#
# Epoch 00114: val_loss did not improve from 0.00074
# Epoch 115/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.2743e-04 - val_loss: 0.1382
#
# Epoch 00115: val_loss did not improve from 0.00074
# Epoch 116/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.3935e-04 - val_loss: 0.1353
#
# Epoch 00116: val_loss did not improve from 0.00074
# Epoch 117/150
# 3424/3424 [==============================] - 1s 209us/step - loss: 4.2727e-04 - val_loss: 0.1382
#
# Epoch 00117: val_loss did not improve from 0.00074
# Epoch 118/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.1381e-04 - val_loss: 0.1376
#
# Epoch 00118: val_loss did not improve from 0.00074
# Epoch 119/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 4.2484e-04 - val_loss: 0.1408
#
# Epoch 00119: val_loss did not improve from 0.00074
# Epoch 120/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 4.2049e-04 - val_loss: 0.1341
#
# Epoch 00120: val_loss did not improve from 0.00074
# Epoch 121/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.0410e-04 - val_loss: 0.1329
#
# Epoch 00121: val_loss did not improve from 0.00074
# Epoch 122/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.0080e-04 - val_loss: 0.1370
#
# Epoch 00122: val_loss did not improve from 0.00074
# Epoch 123/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 4.0525e-04 - val_loss: 0.1406
#
# Epoch 00123: val_loss did not improve from 0.00074
# Epoch 124/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.1336e-04 - val_loss: 0.1360
#
# Epoch 00124: val_loss did not improve from 0.00074
# Epoch 125/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.3544e-04 - val_loss: 0.1294
#
# Epoch 00125: val_loss did not improve from 0.00074
# Epoch 126/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 5.1254e-04 - val_loss: 0.1321
#
# Epoch 00126: val_loss did not improve from 0.00074
# Epoch 127/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 5.8610e-04 - val_loss: 0.1312
#
# Epoch 00127: val_loss did not improve from 0.00074
# Epoch 128/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 0.0013 - val_loss: 0.1529
#
# Epoch 00128: val_loss did not improve from 0.00074
# Epoch 129/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 0.0013 - val_loss: 0.1409
#
# Epoch 00129: val_loss did not improve from 0.00074
# Epoch 130/150
# 3424/3424 [==============================] - 1s 207us/step - loss: 0.0017 - val_loss: 0.1326
#
# Epoch 00130: val_loss did not improve from 0.00074
# Epoch 131/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 0.0013 - val_loss: 0.1261
#
# Epoch 00131: val_loss did not improve from 0.00074
# Epoch 132/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 9.2827e-04 - val_loss: 0.1446
#
# Epoch 00132: val_loss did not improve from 0.00074
# Epoch 133/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 8.7249e-04 - val_loss: 0.1556
#
# Epoch 00133: val_loss did not improve from 0.00074
# Epoch 134/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 6.2600e-04 - val_loss: 0.1362
#
# Epoch 00134: val_loss did not improve from 0.00074
# Epoch 135/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 4.9039e-04 - val_loss: 0.1392
#
# Epoch 00135: val_loss did not improve from 0.00074
# Epoch 136/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.5854e-04 - val_loss: 0.1366
#
# Epoch 00136: val_loss did not improve from 0.00074
# Epoch 137/150
# 3424/3424 [==============================] - 1s 200us/step - loss: 4.3959e-04 - val_loss: 0.1367
#
# Epoch 00137: val_loss did not improve from 0.00074
# Epoch 138/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 4.4396e-04 - val_loss: 0.1351
#
# Epoch 00138: val_loss did not improve from 0.00074
# Epoch 139/150
# 3424/3424 [==============================] - 1s 199us/step - loss: 4.3300e-04 - val_loss: 0.1368
#
# Epoch 00139: val_loss did not improve from 0.00074
# Epoch 140/150
# 3424/3424 [==============================] - 1s 205us/step - loss: 4.2686e-04 - val_loss: 0.1365
#
# Epoch 00140: val_loss did not improve from 0.00074
# Epoch 141/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 4.1762e-04 - val_loss: 0.1370
#
# Epoch 00141: val_loss did not improve from 0.00074
# Epoch 142/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 4.1515e-04 - val_loss: 0.1355
#
# Epoch 00142: val_loss did not improve from 0.00074
# Epoch 143/150
# 3424/3424 [==============================] - 1s 206us/step - loss: 4.0784e-04 - val_loss: 0.1352
#
# Epoch 00143: val_loss did not improve from 0.00074
# Epoch 144/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.0461e-04 - val_loss: 0.1418
#
# Epoch 00144: val_loss did not improve from 0.00074
# Epoch 145/150
# 3424/3424 [==============================] - 1s 202us/step - loss: 4.0227e-04 - val_loss: 0.1392
#
# Epoch 00145: val_loss did not improve from 0.00074
# Epoch 146/150
# 3424/3424 [==============================] - 1s 203us/step - loss: 3.8679e-04 - val_loss: 0.1384
#
# Epoch 00146: val_loss did not improve from 0.00074
# Epoch 147/150
# 3424/3424 [==============================] - 1s 197us/step - loss: 3.9726e-04 - val_loss: 0.1378
#
# Epoch 00147: val_loss did not improve from 0.00074
# Epoch 148/150
# 3424/3424 [==============================] - 1s 204us/step - loss: 4.0125e-04 - val_loss: 0.1445
#
# Epoch 00148: val_loss did not improve from 0.00074
# Epoch 149/150
# 3424/3424 [==============================] - 1s 198us/step - loss: 4.0250e-04 - val_loss: 0.1366
#
# Epoch 00149: val_loss did not improve from 0.00074
# Epoch 150/150
# 3424/3424 [==============================] - 1s 201us/step - loss: 3.9801e-04 - val_loss: 0.1350
#
# Epoch 00150: val_loss did not improve from 0.00074

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test_aug = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test_aug[i]))
